# %% [markdown]
# ---
#
# ### 📓 `notebooks/benin_eda.ipynb`
#
# You’ll make this file **inside the `notebooks` folder.**
# You can create it in **Jupyter Notebook** or **VS Code (Jupyter mode)**.
#
# Add these cells:
#
# **Markdown cell:**
# ```markdown
# # Benin EDA - Interim Submission
# This notebook performs initial data profiling for Benin's solar dataset and outlines the plan for full EDA.

# %%
! pip install pandas numpy seaborn matplotlib scipy
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached matplotlib-3.10.7-cp313-cp313-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached scipy-1.16.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.60.1-cp313-cp313-win_amd64.whl.metadata (114 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp313-cp313-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-12.0.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load data (placeholder)
# If dataset is not yet downloaded, mention in report how it will be added
file_id = "11kVfsA0EubjPo7eOuzJaRIlZmPCJYjPS"
url = f"https://drive.google.com/uc?id={file_id}"
df = pd.read_csv( url)
df.head()
# Out:
# Empty DataFrame
# ...

# %%
# Quick profiling
df.info()
#df.describe()
#df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 3 columns):
# ...

# %% [markdown]
# ## Planned Steps for Full EDA
# - Handle missing values (impute or drop if >5%)
# - Detect outliers using Z-scores for GHI, DNI, DHI, ModA, ModB, WS, WSgust
# - Visualize trends over time (GHI, DNI, DHI vs Timestamp)
# - Analyze Cleaning flag impact on ModA/ModB
# - Plot correlation heatmap (GHI, DNI, DHI, TModA, TModB)
# - Explore RH vs Tamb relationships
# - Export cleaned data to data/benin_clean.csv (excluded from Git)
